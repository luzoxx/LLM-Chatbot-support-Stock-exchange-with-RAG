# %%
import warnings
warnings.filterwarnings("ignore")
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_text_splitters import MarkdownTextSplitter
from sentence_transformers import SentenceTransformer, CrossEncoder
from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams
import pandas as pd
from bert_score import score
from tqdm import tqdm

# %% [markdown]
# ### Reading data

# %%
def read_doc(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.readlines()
        content = [line.strip() for line in content]
        doc = ' '.join(content)
    return doc

# %%
text = read_doc('./Data/outPutTxt.txt')
md = read_doc('./Data/outPutMD.md')

# %% [markdown]
# ### Chunking

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 1500,
    chunk_overlap = 500
)
md_splitter = MarkdownTextSplitter(
    chunk_size = 1500,
    chunk_overlap = 500
)

# %%
doc0 = text_splitter.create_documents([text])
doc1 = md_splitter.create_documents([md])

# %%
text_doc = [doc.page_content for doc in doc0]
md_doc = [doc.page_content for doc in doc1]

# %%
print(len(text_doc))
print(len(md_doc))
# Out:
# 1122
# 650

# %%
for chunk in enumerate(md_doc[:3]):
    print(chunk)
    print('--'*50)
# Out:
# (0, '# Xử lý giao dịch  (*) Thời gian giao dịch phụ thuộc vào thời gian cung cấp dịch vụ của từng ngân hàng.  Riêng rút tiền mặt tại quầy VPBank hạn mức 3.000.000.000 VND/Ngày/TKCK.  Tổ chức tài chính sẽ thông báo thêm thông tin chi tiết về các giao dịch. # Biểu Phí Dịch Vụ Ngân Hàng  |STT|Dịch vụ|Kênh giao dịch|Biểu phí| |---|---|---|---| |1|Chuyển tiền (*)|Rút tại quầy VPBank (theo giờ làm việc của VPBank)|Qua các chi nhánh VPBank tại Hà Nội: Miễn phí; Qua các chi nhánh VPBank khác: 0,03% giá trị giao dịch, tối thiểu 20.000 VND/giao dịch, tối đa 1.500.000 VND/giao dịch| |1|Chuyển tiền (*)|Chuyển tiền nhanh tới Ngân hàng liên kết|Số tiền <= 1 triệu VND: Miễn phí| |1|Chuyển tiền (*)|Chuyển tiền nhanh qua Napas|Số tiền > 1 triệu VND: 3.000 VND/giao dịch| |1|Chuyển tiền (*)|Chuyển tiền thường (Không áp dụng Ngoài giờ)|0,02% giá trị giao dịch, tối thiểu 10.000 VND/giao dịch, tối đa 600.000 VND/giao dịch| |1|Chuyển tiền (*)|Chuyển tiền tới Giấy tờ tùy thân (GTTT) (Không áp dụng Ngoài giờ)|0,025% giá trị giao dịch, tối thiểu 2.000 VND/giao dịch, tối đa 100.000 VND/giao dịch| |1|Chuyển tiền (*)|Chuyển tiền trong VPS|Miễn phí| |2|Chuyển tiền thanh toán hóa đơn|Rút tại quầy VPBank (theo giờ làm việc của VPBank)|Miễn phí| # Biểu Phí Dịch Vụ   |STT|Dịch vụ|Kênh giao dịch|Biểu phí| |---|---|---|---| |3|Nạp tiền vào tài khoản chứng khoán|Nạp tiền qua ứng dụng SmartOne|Miễn phí| |1|Chuyển tiền (*)|Nạp tiền trực tiếp trên ứng dụng của ngân hàng liên kết|VPBank/BIDV/Vietinbank: Miễn phí Các Ngân')
# ----------------------------------------------------------------------------------------------------
# (1, 'giá trị giao dịch, tối thiểu 2.000 VND/giao dịch, tối đa 100.000 VND/giao dịch| |1|Chuyển tiền (*)|Chuyển tiền trong VPS|Miễn phí| |2|Chuyển tiền thanh toán hóa đơn|Rút tại quầy VPBank (theo giờ làm việc của VPBank)|Miễn phí| # Biểu Phí Dịch Vụ   |STT|Dịch vụ|Kênh giao dịch|Biểu phí| |---|---|---|---| |3|Nạp tiền vào tài khoản chứng khoán|Nạp tiền qua ứng dụng SmartOne|Miễn phí| |1|Chuyển tiền (*)|Nạp tiền trực tiếp trên ứng dụng của ngân hàng liên kết|VPBank/BIDV/Vietinbank: Miễn phí Các Ngân hàng khác: Theo biểu phí của Ngân hàng từng thời kỳ| | | |Chuyển tiền vào tài khoản VPS:|Chuyển tiền đến tài khoản định danh Chuyển tiền đến tài khoản ngân hàng của VPS với nội dung theo cú pháp| |1|Chuyển tiền (*)|Nạp tiền tại quầy giao dịch của Ngân hàng|Theo biểu phí của Ngân hàng từng thời kỳ|  (*) Mức phí Dịch vụ chuyển tiền chưa bao gồm VAT (10%). Mức phí thực tế do Ngân hàng thu dựa trên hình thức chuyển tiền tại thời điểm Quý khách thực hiện giao dịch.  Lưu ý:  Giao dịch nộp tiền sau 17:00 ngày làm việc hoặc vào ngày nghỉ, trường hợp TKCK có dư nợ, hệ thống sẽ thực hiện thu nợ vào ngày làm việc kế tiếp. Mọi thắc mắc về giao dịch Nộp/Rút/Chuyển tiền được VPS tiếp nhận qua Tổng đài 1900 6457 và xử lý vào ngày làm việc kế tiếp. Các giao dịch không thành công được VPS đảm bảo xử lý trong 03-05 ngày làm việc.  # BIỂU PHÍ XỬ LÝ TRA SOÁT/ NỘP NHẦM TIỀN VÀO TKCK  |STT|Tên phí|Giá trị giao dịch|Mức thu|Phương thức thu| |---|---|---|---|---| |1|Phí xử lý giao dịch nộp tiền cần tra')
# ----------------------------------------------------------------------------------------------------
# (2, '17:00 ngày làm việc hoặc vào ngày nghỉ, trường hợp TKCK có dư nợ, hệ thống sẽ thực hiện thu nợ vào ngày làm việc kế tiếp. Mọi thắc mắc về giao dịch Nộp/Rút/Chuyển tiền được VPS tiếp nhận qua Tổng đài 1900 6457 và xử lý vào ngày làm việc kế tiếp. Các giao dịch không thành công được VPS đảm bảo xử lý trong 03-05 ngày làm việc.  # BIỂU PHÍ XỬ LÝ TRA SOÁT/ NỘP NHẦM TIỀN VÀO TKCK  |STT|Tên phí|Giá trị giao dịch|Mức thu|Phương thức thu| |---|---|---|---|---| |1|Phí xử lý giao dịch nộp tiền cần tra soát|Dưới 200 triệu VND|20.000 VND/giao dịch|- Khấu trừ tiền phí từ số tiền của GD tra soát/GD nộp nhầm| | | |Từ 200 triệu VND đến dưới 500 triệu VND|100.000 VND/giao dịch|- Khách hàng nộp phí vào tài khoản ngân hàng do VPS chỉ định| |2|Phí xử lý giao dịch nộp tiền nhầm|Từ 500 triệu VND|300.000 VND/giao dịch| |  Lưu ý: Mức phí trên chưa bao gồm VAT (10%).  Trường hợp Quý khách cần hỗ trợ, xin vui lòng liên hệ Tổng đài: 1900 6457 - Phím 2. # Hướng dẫn nạp tiền vào tài khoản chứng khoán VPS tại quầy giao dịch ngân hàng BIDV  BIDV (Ngân hàng TMCP Đầu tư và Phát triển Việt Nam)  Điền thông tin nạp tiền/ chuyển khoản trên giấy nộp tiền mặt/ Ủy nhiệm chi theo một trong hai cách bên dưới hoặc thực hiện theo chỉ dẫn của Giao dịch viên BIDV.  # Cách nạp tiền  |Cách|Số tài khoản thụ hưởng|Tên tài khoản thụ hưởng|Ngân hàng thụ hưởng|Nội dung chuyển tiền| |---|---|---|---|---| |1|9611 + Số tài khoản chứng khoán|Tên chủ Tài khoản chứng khoán|BIDV – CN Hà Thành|Để trống (hoặc điền theo nhu cầu)|')
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Embedding

# %%
model_embedding = SentenceTransformer('dangvantuan/vietnamese-embedding-LongContext', trust_remote_code=True)
model_embedding
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 8192, 'do_lower_case': False}) with Transformer model: VietnameseModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': True, 'pooling_mode_mean_tokens': False, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# )

# %%
embeddingTxt = model_embedding.encode(text_doc)
embeddingMd = model_embedding.encode(md_doc)

# %%
print(embeddingTxt.shape)
print(embeddingMd.shape)
# Out:
# (1122, 768)
# (650, 768)

# %% [markdown]
# ### Creating Vector Database

# %%
QDRANT_API_KEY = ""
QDRANT_URL = ""

# %%
client = QdrantClient(
    url = QDRANT_URL,
    api_key = QDRANT_API_KEY,
    https=True,
    timeout=60
)

# %%
collection_name = "stock_embedding"

# %%
client.recreate_collection(
    collection_name=collection_name,
    vectors_config = VectorParams(size = 768, distance = Distance.COSINE)
)
# Out:
# True

# %%
def upload_vector(embeddings, texts, start_id, source):
    for i, (vt, txt) in enumerate(zip(embeddings, texts)):
        client.upsert(
            collection_name=collection_name,
            points=[
                {
                    "id": start_id + i,
                    "vector": vt.tolist(),
                    "payload": {
                        "text": txt,
                        "metadata": f"Additional info vector {start_id +i }",
                        "source": source
                    }
                }
            ]
        )

# %%
upload_vector(embeddingTxt, text_doc, start_id=0, source="Text")

# %%
start_id_2 = len(embeddingTxt) + 1
start_id_2
# Out:
# 1123

# %%
upload_vector(embeddingMd, md_doc, start_id=start_id_2, source="MarkDown")

# %%
def semantic_search(query_text, top_k):
    query_vector = model_embedding.encode(query_text)

    search_result = client.search(
        collection_name=collection_name,
        query_vector=query_vector.tolist(),
        limit=top_k
    )

    result = []
    for item in search_result:
        result.append(
            {
                'text': item.payload['text'],
                'score': item.score,
                'metadata': item.payload.get('metadata','')
            }
        )
    return result

# %%
query = "giờ mở cửa"
top_result = semantic_search(query, top_k=3)

# %%
for i, result in enumerate(top_result, 1):
    print(f"Kết quả #{i}:")
    print(f"Text: {result['text']}")
    print(f"Score: {result['score']}")
    print(f"Metadata: {result['metadata']}")
# Out:
# Kết quả #1:
# Text: khách hàng mở tại Công ty phải có đủ số lượng chứng khoán muốn bán.  # II. QUY ĐỊNH CHUNG VỀ GIAO DỊCH:  # 1. Nhà đầu tư chỉ được phép mở một TK GDCK tại mỗi Công ty Chứng khoán  Nhà đầu tư có thể sử dụng nhiều tài khoản khác nhau mở tại các công ty chứng khoán khác nhau để thực hiện giao dịch.  # 2. Nhà đầu tư được thực hiện các giao dịch ngược chiều (mua, bán) cùng một loại chứng khoán trong một ngày giao dịch, khi đáp ứng các điều kiện sau:  - Sử dụng một TK mở tại một CTCK để thực hiện cả lệnh mua và bán; - Các giao dịch ngược chiều (mua, bán) trên một tài khoản chỉ áp dụng trong phiên khớp lệnh liên tục, không áp dụng trong phiên khớp lệnh định kỳ.  # 3. Nhà đầu tư không được phép: # III. QUY ĐỊNH GIAO DỊCH TẠI CÁC SỞ GIAO DỊCH CHỨNG KHOÁN:  # A. Chứng Khoán Niêm Yết tại Sở Giao Dịch Chứng Khoán TP.HCM (HSX)  # 1. Thời gian giao dịch:  từ thứ Hai đến thứ Sáu hàng tuần, trừ các ngày nghỉ theo quy định của Bộ luật Lao động và những ngày nghỉ giao dịch theo quy định của cơ quan quản lý.  |Lô giao dịch|Phương thức giao dịch|Giờ giao dịch| |---|---|---| |GD lô chẵn|Cổ phiếu, chứng chỉ quỹ đầu tư, chứng quyền|Khớp lệnh định kỳ mở cửa: 9h00’ đến 9h15’ Khớp lệnh liên tục I: 9h15’ đến 11h30’ Giao dịch thỏa thuận: 9h00’ đến 11h30’ Nghỉ giữa phiên: 11h30’ đến 13h00’ Khớp lệnh liên tục II: 13h00’ đến 14h30’ Khớp lệnh định kỳ đóng cửa: 14h30’ đến 14h45’ Giao dịch thỏa thuận: 13h00’ đến 15h00’| | |Trái phiếu|Giao dịch thỏa thuận: 9h00’ đến 11h30’ Nghỉ giữa phiên: 11h30’ đến 13h00’
# Score: 0.48178005
# Metadata: Additional info vector 1323
# Kết quả #2:
# Text: gian giao dịch cụ thề như sau:  - Đối với giao dịch Cổ phiếu, chứng chỉ quỹ ETF: Phiên Phương thức giao Giờ giao dịch dịch Khớp lệnh liên tục 09h00 - 11h30  Loại lệnh giao dịch  Lệnh giới hạn (LO),  I  Lệnh thị trường giới hạn (MTL), Lệnh thị trường khớp toàn bộ hoặc hủy (MOK), Lệnh thị trường khớp và hủy (MAK)  Giao dịch thỏa thuận  09h00 - 11h30 11h30 - 13h00  Nghỉ giữa hai phiên sáng- chiều Khớp lệnh liên tục  13h00 - 14h30  Lệnh giới hạn (LO),  II  Lệnh thị trường giới hạn  4  (MTL), Lệnh thị trường khớp toàn bộ hoặc hủy (MOK), Lệnh thị trường khớp và hủy (MAK)  Khớp lệnh định kỳ đóng cửa  Giao dịch thỏa  thuận  Khớp lệnh sau giờ  14h30 - 14h45  13h00 - 15h00 14h45 - 15h00  Lệnh giới hạn (LO),  Phiên chiều  Lệnh giao dịch tại mức khớp lệnh xác định giá  đóng cửa (ATC)  Lệnh giao dịch khớp lệnh  sau giờ (PLO)   * Lưu ý: Thời gian giao dịch áp dụng đối với giao dịch lô chẵn từ 9h00 đến 15h00 và giao dịch lô lẻ từ 9h00 đền 14h30. Trong thời gian nghỉ giữa hai phiên sáng - chiều, Thành viên không được phép:  - Nhập lệnh, sửa, hủy lệnh của giao dịch khớp lệnh;  - Quảng cáo giao dịch thỏa thuận, hủy quảng cáo giao dịch thỏa thuận;  - Thực hiện giao dịch thỏa thuận, hủy giao dịch thỏa thuận.  - Đối với giao dịch Trái phiếu:  Phiên Phương thức giao dịch Giờ giao dịch Loại lệnh giao dịch Phiên sáng Khớp lệnh liên tục I 09h00 - 11h30 Giao dịch thỏả thuận 09h00 - 11h30  Nghỉ giữa hai phiên sáng- chiều 11h30 - 13h00 Lệnh giới hạn (LO) Phiên chiêu Khớp lệnh liên tục II 13h00 - 14h30
# Score: 0.43301132
# Metadata: Additional info vector 526
# Kết quả #3:
# Text: sau:",Với những hợp đồng mở mới trong ngày:Lãi/lỗ vị thế mới mở = (Giá thanh toán cuối ngày – Giá giao dịch) x Hệ số nhân x Số lượng hợp đồng.Với những hợp đồng đang nắm giữ:Lãi/lỗ vị thế đã có = (Giá thanh toán cuối ngày – Giá thanh toán cuối ngày liền trước) x Hệ số nhân x Số lượng hợp đồng.,Thời gian thanh toán:,Nếu tài khoản chứng khoán phái sinh của Nhà đầu tư lỗ ròng: Nhà đầu tư phải thanh toán đầy đủ toàn bộ số lỗ phát sinh chậm nhất trước 8h30 sáng ngày làm việc kế tiếp.Nếu tài khoản chứng khoán phái sinh của Nhà đầu tư lãi ròng: Nhà đầu tư sẽ nhận được đầy đủ số tiền lãi phát sinh trước 9h sáng ngày làm việc kế tiếp. "Khi giao dịch chứng khoán phái sinh, tôi sẽ phải thanh toán các khoản chi phí nào?" "Khi giao dịch chứng khoán phái sinh, Nhà đầu tư cần thanh toán các khoản chi phí như sau:",Phí giao dịch trả Sở giao dịchPhí giao dịch trả VPSThuế giao dịchPhí quản lý vị thế trả VSD (khi giữ vị thế qua đêm)Phí quản lý tài sản ký quỹ trả VSD (khi giữ tiền ký quỹ hoặc giữ vị thế qua đêm tại VSD),Mức thu chi tiết đối với các khoản phí này được thay đổi và áp dụng theo quy định từng thời kỳ của Cơ quan quản lý và của VPS. VPS có những loại lệnh điều kiện nào trong giao dịch đầu tư chứng khoán phái sinh? "Hiện tại VPS có hệ thống các loại lệnh điều kiện để hỗ trợ Quý khách trong quá trình giao dịch chứng khoán phái sinh, bao gồm các lệnh sau:","Lệnh Stop Order: lệnh đặt chờ, với giá đặt và giá kích hoạt được xác định trước. Khi giá thị trường vượt hơn hoặc giảm so với giá
# Score: 0.42493868
# Metadata: Additional info vector 1728

# %% [markdown]
# ### Setting LLM

# %%
qdrant_client = QdrantClient(
    url=QDRANT_URL,
    api_key=QDRANT_API_KEY,
    https=True
)

# %%
bi_encoder = SentenceTransformer('dangvantuan/vietnamese-embedding-LongContext', trust_remote_code=True)
cross_encoder = CrossEncoder('itdainb/PhoRanker')

# %% [markdown]
# ### Local LLM

# %%
from openai import OpenAI

llm_client = OpenAI(base_url="http://localhost:1234/v1", api_key="lm-studio")

# %%
def semantic_search_rerank(query_text, top_k=15, rerank_top_k=5):
    query_vector = bi_encoder.encode(query_text)

    search_result = qdrant_client.search(
        collection_name=collection_name,
        query_vector=query_vector.tolist(),
        limit=top_k
    )

    rerank_pairs = [(query_text, item.payload['text']) for item in search_result]
    rerank_score = cross_encoder.predict(rerank_pairs)

    for i, item in enumerate(search_result):
        item.score = float(rerank_score[i])
    
    rerank_results = sorted(search_result, key=lambda x: x.score, reverse=True)[:rerank_top_k]

    return [item.payload['text'] for item in rerank_results]

# %%
def generate_answer(query, context):
    prompt = f"""
        Bạn là một người sử dụng tiếng Việt thành thạo.
        Bạn cũng là một chuyên gia tư vấn về lĩnh vực chứng khoán.
        Dựa vào ngữ cảnh dưới đây, hãy trả lời câu hỏi một cách ngắn gọn và chính xác nhất bằng Tiếng Việt.
        Nếu không biết câu trả lời, hãy lịch sử bảo rằng không biết và không bịa đặt nội dung.
        Ngữ cảnh: {context}
        Câu hỏi: {query}
        Câu trả lời (bằng Tiếng Việt):"""
    
    completion = llm_client.chat.completions.create(
        model = "RichardErkhov/vilm_-_vietcuna-7b-v3-gguf/vietcuna-7b-v3.Q5_K_S.gguf",
        messages=[
            {
                "role": "system",
                "content": "Bạn là trợ lý AI sử dụng tiếng Việt thành thạo."
            },
            {
                "role": "user",
                "content": prompt
            }
        ],
        temperature=0.8,
        max_tokens=300
    )

    return completion.choices[0].message.content

# %%
def generate_answer(query, context):
    prompt = f"""
    Bạn là một người sử dụng tiếng việt thành thạo.
    Dựa vào ngữ cảnh sau đây, hãy trả lời câu hỏi một cách ngắn gọn và chính xác bằng Tiếng Việt.
    Nếu không biết câu trả lời hãy lịch sự bảo không biết, không bịa đặt nội dung:

    Ngữ cảnh: {context}

    Câu hỏi: {query}

    Trả lời:"""

    completion = llm_client.chat.completions.create(
        model="nguyenviet/PhoGPT-7B5-Instruct-GGUF/PhoGPT-7B5-Instruct-q5_k_m.gguf",
        messages=[
            {"role": "system", "content": "Bạn là trợ lý AI sử dụng tiếng Việt thành thạo."},
            {"role": "user", "content": prompt}
        ],
        temperature=0.6,
        max_tokens=300,
        # top_p=0.9,
        # frequency_penalty=0.3,
        # presence_penalty=0.3
    )

    return completion.choices[0].message.content

# %% [markdown]
# ### API LLM

# %%
XAI_API_KEY = ""

# %%
from openai import OpenAI

# %%
client = OpenAI(
  api_key=XAI_API_KEY,
  base_url="https://api.x.ai/v1",
)

# %%
def generate_answer(query, context):
    prompt = f"""
            Bạn là một người sử dụng tiếng Việt thành thạo.
            Bạn cũng là một chuyên gia tư vấn về lĩnh vực chứng khoán.
            Dựa vào ngữ cảnh dưới đây, hãy trả lời câu hỏi một cách ngắn gọn và chính xác nhất bằng Tiếng Việt.
            Nếu không biết câu trả lời, hãy lịch sử bảo rằng không biết và không bịa đặt nội dung.
            Luôn trả lời bằng Tiếng Việt, không sử dụng bất cứ ngôn ngữ nào khác:

        Ngữ cảnh: {context}

        Câu hỏi: {query}

        Câu trả lời (bằng Tiếng Việt):"""

    completion = client.chat.completions.create(
        messages=[
            {
                "role": "system",
                "content": "Bạn là trợ lý AI sử dụng tiếng Việt thành thạo. Trả lời ngắn gọn, chính xác, không thêm thông tin ngoài lề"
            },
            {
                "role": "user",
                "content": prompt,
            }
        ],
        model="grok-2-1212",
    )

    return completion.choices[0].message.content

# %%
GROQ_API_KEY = ""

# %%
from groq import Groq

client = Groq(
    api_key=GROQ_API_KEY
)

# %%
def generate_answer(query, context):
    prompt = f"""
            Bạn là một người sử dụng tiếng Việt thành thạo.
            Bạn cũng là một chuyên gia tư vấn về lĩnh vực chứng khoán.
            Dựa vào ngữ cảnh dưới đây, hãy trả lời câu hỏi một cách ngắn gọn và chính xác nhất bằng Tiếng Việt.
            Nếu không biết câu trả lời, hãy lịch sử bảo rằng không biết và không bịa đặt nội dung.
            Luôn trả lời bằng Tiếng Việt, không sử dụng bất cứ ngôn ngữ nào khác:

        Ngữ cảnh: {context}

        Câu hỏi: {query}

        Câu trả lời (bằng Tiếng Việt):"""

    completion = client.chat.completions.create(
        messages=[
            {
                "role": "system",
                "content": "Bạn là trợ lý AI sử dụng tiếng Việt thành thạo. Trả lời ngắn gọn, chính xác, không thêm thông tin ngoài lề"
            },
            {
                "role": "user",
                "content": prompt,
            }
        ],
        model="llama3-8b-8192",
    )

    return completion.choices[0].message.content

# %% [markdown]
# ### Generating from LLM

# %%
def qa_system(query):
    relevant_passages = semantic_search_rerank(query)
    context = " ".join(relevant_passages)
    answer = generate_answer(query, context)
    return answer

# %%
user_query = "Tôi có thể mở nhiều tài khoản chứng khoán tại VPS không?"
response = qa_system(user_query)

print(f"Câu hỏi: {user_query}")
print(f"Trả lời: {response}")
# Out:
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Câu hỏi: Tôi có thể mở nhiều tài khoản chứng khoán tại VPS không?
# Trả lời: Theo quy định của cơ quan quản lý, mỗi khách hàng chỉ có thể sử dụng chứng minh nhân dân/căn cước công dân còn hiệu lực của cá nhân đó để mở 01 tài khoản giao dịch chứng khoán tại một công ty chứng khoán. Quý khách có thể mở tài khoản giao dịch chứng khoán tại các công ty chứng khoán khác nhau.

# %% [markdown]
# ### Testing LLM response

# %% [markdown]
# #### API LLM

# %%
data = pd.read_csv('./Data/sm_test.csv')
data.tail()
# Out:
#                                            Questions                                            Answers
# 5  Tôi có thể mở tài khoản giao dịch tại VPS qua ...  "Để mở tài khoản giao dịch tại VPS, Quý khách ...
# 6  Tôi có thể mở tài khoản tại VPS vào thời điểm ...  "Hệ thống mở tài khoản trực tuyến của VPS hoạt...
# 7  "Tôi quét QR chuyển tiền, người nhận chưa nhận...  • Quý khách vui lòng liên hệ tới Tổng đài 1900...
# 8  Nạp tiền vào tài khoản chứng khoán từ tài khoả...  Hạn mức nạp tiền vào tài khoản chứng khoán (TK...
# 9  "Tôi thấy khi tạo mã QR nhận tiền từ TKCK luôn...  "Quý khách có thể đổi sang các loại tài khoản ...

# %%
def evaluate_response(csv_file_path):
    df = pd.read_csv(csv_file_path)

    questions = df['Questions'].tolist()
    reference_answers = df['Answers'].tolist()

    llm_answers = []
    for quest in tqdm(questions, desc="Generating LLM answers"):
        each_llm_answer = qa_system(quest)
        llm_answers.append(each_llm_answer)

    P, R, F1 = score(llm_answers, reference_answers, lang="vi", verbose=True)

    avg_precision = P.mean().item()
    avg_recall = R.mean().item()
    avg_f1 = F1.mean().item()

    return {
        'avg_precision': avg_precision,
        'avg_recall': avg_recall,
        'avg_f1': avg_f1,
        'individual_scores': list(zip(questions, reference_answers, llm_answers, F1.tolist()))
    }

# %%
csv_file_path = './Data/test_1_100.csv'
result = evaluate_response(csv_file_path=csv_file_path)
# Out:
# Generating LLM answers:   0%|          | 0/99 [00:00<?, ?it/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:   1%|          | 1/99 [00:15<25:04, 15.35s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:   2%|▏         | 2/99 [00:19<14:12,  8.79s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:   3%|▎         | 3/99 [00:21<09:17,  5.80s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:   4%|▍         | 4/99 [00:24<07:01,  4.44s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:   5%|▌         | 5/99 [00:26<05:43,  3.65s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:   6%|▌         | 6/99 [00:28<04:54,  3.17s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:   7%|▋         | 7/99 [00:30<04:21,  2.84s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:   8%|▊         | 8/99 [00:33<04:01,  2.66s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:   9%|▉         | 9/99 [00:35<03:44,  2.50s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:  10%|█         | 10/99 [00:37<03:29,  2.36s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:  11%|█         | 11/99 [00:39<03:22,  2.30s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:  12%|█▏        | 12/99 [00:41<03:23,  2.34s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:  13%|█▎        | 13/99 [00:44<03:24,  2.38s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# ...
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:  96%|█████████▌| 95/99 [06:43<00:17,  4.39s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:  97%|█████████▋| 96/99 [06:48<00:14,  4.68s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:  98%|█████████▊| 97/99 [06:53<00:09,  4.66s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:  99%|█████████▉| 98/99 [06:57<00:04,  4.55s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers: 100%|██████████| 99/99 [07:02<00:00,  4.26s/it]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/4 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/2 [00:00<?, ?it/s]
# done in 18.41 seconds, 5.38 sentences/sec

# %%
print(f"Average Precision: {result['avg_precision']:.4f}")
print(f"Average Recall: {result['avg_recall']:.4f}")
print(f"Average F1 Score: {result['avg_f1']:.4f}")
# Out:
# Average Precision: 0.8514
# Average Recall: 0.8194
# Average F1 Score: 0.8341

# %%
print("\nMột số ví dụ cụ thể:")
for question, ref_answer, llm_answer, f1_score in result['individual_scores'][:5]:
    print(f"Question: {question}")
    print('--'*30)
    print(f"Reference Answer: {ref_answer}")
    print('--'*30)
    print(f"LLM Answer: {llm_answer}")
    print('--'*30)
    print(f"F1 Score: {f1_score:.4f}\n")
    print('##'*50)
# Out:
# Một số ví dụ cụ thể:
# Question: Tôi có thể mở nhiều tài khoản chứng khoán tại VPS không?
# ------------------------------------------------------------
# Reference Answer: "Theo quy định của cơ quan quản lý, mỗi khách hàng chỉ có thể sử dụng chứng minh nhân dân/căn cước công dân còn hiệu lực của cá nhân đó để mở 01 tài khoản giao dịch chứng khoán tại một công ty chứng khoán.Quý khách có thể mở tài khoản giao dịch chứng khoán tại các công ty chứng khoán khác nhau."
# ------------------------------------------------------------
# LLM Answer: Theo quy định của cơ quan quản lý, mỗi khách hàng chỉ có thể sử dụng chứng minh nhân dân/căn cước công dân còn hiệu lực của cá nhân đó để mở 01 tài khoản giao dịch chứng khoán tại một công ty chứng khoán. Do đó, bạn chỉ có thể mở 01 tài khoản chứng khoán tại VPS.
# ------------------------------------------------------------
# F1 Score: 0.9275
#
# ####################################################################################################
# Question: Tôi muốn ủy quyền cho người khác để thực hiện mở tài khoản chứng khoán thì cần thủ tục gì?
# ------------------------------------------------------------
# Reference Answer: "Theo quy định của VPS, Quý khách không được thực hiện ủy quyền cho người khác để thực hiện mở tài khoản. Việc mở tài khoản chứng khoán phải được thực hiện trực tiếp từ khách hàng có nhu cầu.Sau khi mở tài khoản chứng khoán, Quý khách có thể thực hiện ủy quyền giao dịch cho người khác nếu hồ sơ ủy quyền hợp lệ. Quý khách có thể mở tài khoản trực tuyến tại VPS qua những ứng dụng giao dịch sau:",Ứng dụng VPS SmartOne: http://bit.ly/319dmz8,,Website: https://openaccount.vps.com.vn/
# ------------------------------------------------------------
# LLM Answer: Theo quy định của VPS, Quý khách không được thực hiện ủy quyền cho người khác để thực hiện mở tài khoản. Việc mở tài khoản chứng khoán phải được thực hiện trực tiếp từ khách hàng có nhu cầu. Sau khi mở tài khoản chứng khoán, Quý khách có thể thực hiện ủy quyền giao dịch cho người khác nếu hồ sơ ủy quyền hợp lệ.
# ------------------------------------------------------------
# F1 Score: 0.8511
#
# ####################################################################################################
# Question: "Tôi đã mở tài khoản trực tuyến trên ứng dụng VPS SmartOne, vậy tôi có phải gửi hồ sơ bản cứng tới VPS không?"
# ------------------------------------------------------------
# Reference Answer: "Trường hợp Quý khách thực hiện mở tài khoản chứng khoán trên ứng dụng VPS SmartOne và đã xác thực eKYC thành công, tài khoản sẽ được kích hoạt và Quý khách không cần gửi hồ sơ bản cứng tới VPS để hoàn thiện thủ tục mở tài khoản."
# ------------------------------------------------------------
# LLM Answer: "Trường hợp Quý khách thực hiện mở tài khoản chứng khoán trên ứng dụng VPS SmartOne và đã xác thực eKYC thành công, tài khoản sẽ được kích hoạt và Quý khách không cần gửi hồ sơ bản cứng tới VPS để hoàn thiện thủ tục mở tài khoản."
# ------------------------------------------------------------
# F1 Score: 1.0000
#
# ####################################################################################################
# Question: Tôi là người nước ngoài và muốn mở tài khoản giao dịch chứng khoán thì cần làm những thủ tục gì?
# ------------------------------------------------------------
# Reference Answer: "Quý khách có thể đến trực tiếp Trụ sở chính/chi nhánh của VPS để thực hiện thủ tục mở tài khoản. Đối với nhà đầu tư cá nhân nước ngoài, Quý khách cần chuẩn bị các giấy tờ sau:- 03 bản sao công chứng hộ chiếu còn hiệu lực với thời hạn trong vòng 06 tháng;- Bản chụp Giấy mở tài khoản vốn đầu tư gián tiếp tại Ngân hàng;- Bản sao giấy chứng nhận đăng ký mã số giao dịch chứng khoán (trading code) hợp lệ (nếu có).Đối với nhà đầu tư Tổ chức, Quý khách vui lòng liên hệ trực tiếp tại các điểm giao dịch hoặc Tổng đài 1900 6457 để được hỗ trợ thông tin."
# ------------------------------------------------------------
# LLM Answer: Tại VPS, Quý khách có thể mở tài khoản giao dịch chứng khoán như sau:
#
# * Nếu là nhà đầu tư cá nhân nước ngoài, Quý khách cần chuẩn bị các giấy tờ sau:
# 	+ 03 bản sao công chứng hộ chiếu còn hiệu lực với thời hạn trong vòng 06 tháng
# 	+ Bản chụp Giấy mở tài khoản vốn đầu tư gián tiếp tại Ngân hàng
# 	+ Bản sao giấy chứng nhận đăng ký mã số giao dịch chứng khoán (trading code) hợp lệ (nếu có)
# * Quý khách có thể đến trực tiếp Trụ sở chính/chi nhánh cả của VPS để thực hiện thủ tục mở tài khoản.
#
# Chúc Quý khách giao dịch an toàn và đầu tư hiệu quả cùng VPS!
# ------------------------------------------------------------
# F1 Score: 0.8843
#
# ####################################################################################################
# Question: "Để mở tài khoản tại VPS, tôi cần có giấy tờ gì?"
# ------------------------------------------------------------
# Reference Answer: "Để thực hiện mở tài khoản chứng khoán tại VPS, Quý khách cần cung cấp một trong các loại giấy tờ sau:",Căn cước công dân còn hiệu lực.Căn cước còn hiệu lực.
# ------------------------------------------------------------
# LLM Answer: Theo quy định của VPS, để mở tài khoản chứng khoán tại VPS, Quý khách cần cung cấp một trong các loại giấy tờ sau: Căn cước công dân còn hiệu lực.
# ------------------------------------------------------------
# F1 Score: 0.9081
#
# ####################################################################################################

# %%
import gradio as gr

# %%
iface = gr.Interface(
 fn=qa_system,
 inputs=[gr.Textbox(label="Question")],  # Pass input as a list
 outputs=[gr.Textbox(label="Generated Response")],  # Pass output as a list
 title="Stock Chatbot support for VPS",
#  description="Enter a question and get a generated response based on the retrieved text.",
)

iface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Traceback (most recent call last):
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/httpx/_transports/default.py", line 72, in map_httpcore_exceptions
#     yield
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/httpx/_transports/default.py", line 236, in handle_request
#     resp = self._pool.handle_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py", line 216, in handle_request
#     raise exc from None
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py", line 196, in handle_request
#     response = connection.handle_request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/httpcore/_sync/connection.py", line 99, in handle_request
#     raise exc
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/httpcore/_sync/connection.py", line 76, in handle_request
#     stream = self._connect(request)
#              ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/httpcore/_sync/connection.py", line 122, in _connect
#     stream = self._network_backend.connect_tcp(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/httpcore/_backends/sync.py", line 205, in connect_tcp
#     with map_exceptions(exc_map):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py", line 158, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/httpcore/_exceptions.py", line 14, in map_exceptions
#     raise to_exc(exc) from exc
# httpcore.ConnectTimeout: timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/qdrant_client/http/api_client.py", line 106, in send_inner
#     response = self._client.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/httpx/_client.py", line 926, in send
#     response = self._send_handling_auth(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/httpx/_client.py", line 954, in _send_handling_auth
#     response = self._send_handling_redirects(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/httpx/_client.py", line 991, in _send_handling_redirects
#     response = self._send_single_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/httpx/_client.py", line 1027, in _send_single_request
#     response = transport.handle_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/httpx/_transports/default.py", line 235, in handle_request
#     with map_httpcore_exceptions():
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py", line 158, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/httpx/_transports/default.py", line 89, in map_httpcore_exceptions
#     raise mapped_exc(message) from exc
# httpx.ConnectTimeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/gradio/queueing.py", line 536, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/gradio/route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/gradio/blocks.py", line 1935, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/gradio/blocks.py", line 1520, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 2177, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 859, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/gradio/utils.py", line 826, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/var/folders/pr/jq0v9vp91b52cygynx4lfvw00000gn/T/ipykernel_72486/1652853652.py", line 2, in qa_system
#     relevant_passages = semantic_search_rerank(query)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/pr/jq0v9vp91b52cygynx4lfvw00000gn/T/ipykernel_72486/2314228934.py", line 4, in semantic_search_rerank
#     search_result = qdrant_client.search(
#                     ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/qdrant_client/qdrant_client.py", line 387, in search
#     return self._client.search(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/qdrant_client/qdrant_remote.py", line 563, in search
#     search_result = self.http.points_api.search_points(
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/qdrant_client/http/api/points_api.py", line 1616, in search_points
#     return self._build_for_search_points(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/qdrant_client/http/api/points_api.py", line 750, in _build_for_search_points
#     return self.api_client.request(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/qdrant_client/http/api_client.py", line 79, in request
#     return self.send(request, type_)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/qdrant_client/http/api_client.py", line 96, in send
#     response = self.middleware(request, self.send_inner)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/qdrant_client/http/api_client.py", line 205, in __call__
#     return call_next(request)
#            ^^^^^^^^^^^^^^^^^^
#   File "/Users/toan/Working/AI/pythonCS/lib/python3.11/site-packages/qdrant_client/http/api_client.py", line 108, in send_inner
#     raise ResponseHandlingException(e)
# qdrant_client.http.exceptions.ResponseHandlingException: timed out
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.

# %% [markdown]
# #### Local LLM

# %%
csv_file_path = './Data/test_1_100.csv'
result = evaluate_response(csv_file_path=csv_file_path)
# Out:
# Generating LLM answers:   0%|          | 0/99 [00:00<?, ?it/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:   1%|          | 1/99 [00:27<45:28, 27.84s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:   2%|▏         | 2/99 [00:57<46:48, 28.96s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:   3%|▎         | 3/99 [01:23<44:06, 27.57s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:   4%|▍         | 4/99 [02:22<1:03:29, 40.10s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:   5%|▌         | 5/99 [03:03<1:03:22, 40.45s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:   6%|▌         | 6/99 [03:49<1:05:25, 42.21s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:   7%|▋         | 7/99 [04:23<1:00:38, 39.55s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:   8%|▊         | 8/99 [04:54<55:57, 36.89s/it]  Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:   9%|▉         | 9/99 [05:14<47:30, 31.67s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:  10%|█         | 10/99 [05:45<46:33, 31.38s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:  11%|█         | 11/99 [06:24<49:31, 33.76s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:  12%|█▏        | 12/99 [07:09<53:54, 37.17s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:  13%|█▎        | 13/99 [07:54<56:24, 39.36s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# ...
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:  96%|█████████▌| 95/99 [2:01:48<03:56, 59.17s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:  97%|█████████▋| 96/99 [2:02:20<02:33, 51.08s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:  98%|█████████▊| 97/99 [2:03:08<01:39, 49.94s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers:  99%|█████████▉| 98/99 [2:04:08<00:53, 53.24s/it]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Generating LLM answers: 100%|██████████| 99/99 [2:04:57<00:00, 75.73s/it]
# calculating scores...
# computing bert embedding.
#   0%|          | 0/4 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/2 [00:00<?, ?it/s]
# done in 19.21 seconds, 5.15 sentences/sec

# %%
print(f"Average Precision: {result['avg_precision']:.4f}")
print(f"Average Recall: {result['avg_recall']:.4f}")
print(f"Average F1 Score: {result['avg_f1']:.4f}")
# Out:
# Average Precision: 0.7180
# Average Recall: 0.7061
# Average F1 Score: 0.7092

# %%
print("\nMột số ví dụ cụ thể:")
for question, ref_answer, llm_answer, f1_score in result['individual_scores'][:5]:
    print(f"Question: {question}")
    print('--'*30)
    print(f"Reference Answer: {ref_answer}")
    print('--'*30)
    print(f"LLM Answer: {llm_answer}")
    print('--'*30)
    print(f"F1 Score: {f1_score:.4f}\n")
    print('##'*50)
# Out:
# Một số ví dụ cụ thể:
# Question: Tôi có thể mở nhiều tài khoản chứng khoán tại VPS không?
# ------------------------------------------------------------
# Reference Answer: "Theo quy định của cơ quan quản lý, mỗi khách hàng chỉ có thể sử dụng chứng minh nhân dân/căn cước công dân còn hiệu lực của cá nhân đó để mở 01 tài khoản giao dịch chứng khoán tại một công ty chứng khoán.Quý khách có thể mở tài khoản giao dịch chứng khoán tại các công ty chứng khoán khác nhau."
# ------------------------------------------------------------
# LLM Answer: Bạn có thể mở nhiều tài khoản chứng khoán tại VPS.
# ------------------------------------------------------------
# F1 Score: 0.7535
#
# ####################################################################################################
# Question: Tôi muốn ủy quyền cho người khác để thực hiện mở tài khoản chứng khoán thì cần thủ tục gì?
# ------------------------------------------------------------
# Reference Answer: "Theo quy định của VPS, Quý khách không được thực hiện ủy quyền cho người khác để thực hiện mở tài khoản. Việc mở tài khoản chứng khoán phải được thực hiện trực tiếp từ khách hàng có nhu cầu.Sau khi mở tài khoản chứng khoán, Quý khách có thể thực hiện ủy quyền giao dịch cho người khác nếu hồ sơ ủy quyền hợp lệ. Quý khách có thể mở tài khoản trực tuyến tại VPS qua những ứng dụng giao dịch sau:",Ứng dụng VPS SmartOne: http://bit.ly/319dmz8,,Website: https://openaccount.vps.com.vn/
# ------------------------------------------------------------
# LLM Answer: Để thực hiện ủy quyền giao dịch cho người khác để thực hiện mở tài khoản chứng khoán, bạn cần cung cấp một trong các loại giấy tờ sau đây:
# - Căn cước công dân còn hiệu lực.
# - Chứng minh thư.
# - Bản chụp của Giấy mở tài khoản vốn đầu tư gián tiếp tại Ngân hàng.
# - Hồ sơ ủy thác hợp lệ.
# ------------------------------------------------------------
# F1 Score: 0.6941
#
# ####################################################################################################
# Question: "Tôi đã mở tài khoản trực tuyến trên ứng dụng VPS SmartOne, vậy tôi có phải gửi hồ sơ bản cứng tới VPS không?"
# ------------------------------------------------------------
# Reference Answer: "Trường hợp Quý khách thực hiện mở tài khoản chứng khoán trên ứng dụng VPS SmartOne và đã xác thực eKYC thành công, tài khoản sẽ được kích hoạt và Quý khách không cần gửi hồ sơ bản cứng tới VPS để hoàn thiện thủ tục mở tài khoản."
# ------------------------------------------------------------
# LLM Answer: Không.
# ------------------------------------------------------------
# F1 Score: 0.5432
#
# ####################################################################################################
# Question: Tôi là người nước ngoài và muốn mở tài khoản giao dịch chứng khoán thì cần làm những thủ tục gì?
# ------------------------------------------------------------
# Reference Answer: "Quý khách có thể đến trực tiếp Trụ sở chính/chi nhánh của VPS để thực hiện thủ tục mở tài khoản. Đối với nhà đầu tư cá nhân nước ngoài, Quý khách cần chuẩn bị các giấy tờ sau:- 03 bản sao công chứng hộ chiếu còn hiệu lực với thời hạn trong vòng 06 tháng;- Bản chụp Giấy mở tài khoản vốn đầu tư gián tiếp tại Ngân hàng;- Bản sao giấy chứng nhận đăng ký mã số giao dịch chứng khoán (trading code) hợp lệ (nếu có).Đối với nhà đầu tư Tổ chức, Quý khách vui lòng liên hệ trực tiếp tại các điểm giao dịch hoặc Tổng đài 1900 6457 để được hỗ trợ thông tin."
# ------------------------------------------------------------
# LLM Answer: Để thực hiện mở tài khoản chứng khoán tại VPS, bạn có thể chọn một trong các cách sau:
# 1. Trực tiếp đến Trụ sở chính/chi nhánh của VPS.
# 2. Gọi điện cho Trung tâm Giao dịch Chứng khoán TP HCM (GDCK) qua số 1900 6457.
# 3. Liên hệ với nhà môi giới hoặc đại lý chứng khoán của bạn.
#
# Để mở tài khoản giao dịch chứng khoán tại VPS, bạn có thể lựa chọn một trong những cách sau:
# 1. Mở tài khoản trực tuyến trên ứng dụng VPS SmartOne.
# 2. Gửi hồ sơ bản cứng tới Trụ sở chính/chi nhánh của VPS hoặc gửi email cho Phòng giao dịch trực tuyến của VPS.
#
# Nếu không chắc chắn về yêu cầu mở tài khoản giao dịch chứng khoán tại VPS, bạn có thể gọi điện đến Trung tâm Giao dịch Chứng khoán TP HCM (GDCK) để được hướng dẫn. Họ sẽ cung cấp thông tin cần thiết và hướng dẫn bạn thực hiện việc mở tài khoản giao dịch chứng khoán tại VPS.
#
# Nếu không chắc chắn về yêu cầu mở tài khoản giao dịch chứng khoán tại VPS, bạn có thể liên hệ với Trung tâm Giao dịch Chứng khoán TP HCM (GDCK) để được hướng dẫn. Họ sẽ cung cấp thông tin cần thiết và hướng dẫn bạn thực hiện việc mở tài khoản giao dịch chứng khoán tại VPS.
#
# Nếu không chắc chắn về yêu cầu mở tài khoản giao dịch chứng
# ------------------------------------------------------------
# F1 Score: 0.6766
#
# ####################################################################################################
# Question: "Để mở tài khoản tại VPS, tôi cần có giấy tờ gì?"
# ------------------------------------------------------------
# Reference Answer: "Để thực hiện mở tài khoản chứng khoán tại VPS, Quý khách cần cung cấp một trong các loại giấy tờ sau:",Căn cước công dân còn hiệu lực.Căn cước còn hiệu lực.
# ------------------------------------------------------------
# LLM Answer: Để mở tài khoản tại VPS, bạn cần cung cấp một trong các loại giấy tờ sau đây:
#
# 1. Căn cước công dân còn hiệu lực.
#
# 2. Chứng minh thư còn hiệu lực.
#
# 3. Giấy chứng nhận đăng ký mã số giao dịch chứng khoán (trading code).
#
# 4. Hộ chiếu.
#
# 5. Các loại giấy tờ khác có thể được yêu cầu tùy thuộc vào từng trường hợp và quy định cụ thể của VPS.
#
# Lưu ý: Nếu không biết câu trả lời, hãy sử dụng lịch sự để lịch sự bày tỏ rằng bạn không biết hoặc không bịa đặt nội dung.
# ------------------------------------------------------------
# F1 Score: 0.7557
#
# ####################################################################################################

# %% [markdown]
# #### PhoGPT Humaneval

# %%
print("\nMột số ví dụ cụ thể:")
for question, ref_answer, llm_answer, f1_score in result['individual_scores'][:5]:
    print(f"Question: {question}")
    print('--'*30)
    print(f"Reference Answer: {ref_answer}")
    print('--'*30)
    print(f"LLM Answer: {llm_answer}")
    print('--'*30)
    print(f"F1 Score: {f1_score:.4f}\n")
    print('##'*50)
# Out:
# Một số ví dụ cụ thể:
# Question: Tôi có thể mở nhiều tài khoản chứng khoán tại VPS không?
# ------------------------------------------------------------
# Reference Answer: "Theo quy định của cơ quan quản lý, mỗi khách hàng chỉ có thể sử dụng chứng minh nhân dân/căn cước công dân còn hiệu lực của cá nhân đó để mở 01 tài khoản giao dịch chứng khoán tại một công ty chứng khoán.Quý khách có thể mở tài khoản giao dịch chứng khoán tại các công ty chứng khoán khác nhau."
# ------------------------------------------------------------
# LLM Answer: Theo quy định của VPS, mỗi khách hàng chỉ được sử dụng chứng minh nhân dân/Căn cước công dân có hạn sử dụng để mở tài khoản giao dịch. Vì vậy, nếu muốn mở nhiều tài khoản giao dịch chứng khoán, quý khách cần liên hệ với chi nhánh/phòng giao dịch gần nhất của VPS để thực hiện các thủ tục liên quan đến việc mở tài khoản mới.
# ------------------------------------------------------------
# F1 Score: 0.8058
#
# ####################################################################################################
# Question: Tôi muốn ủy quyền cho người khác để thực hiện mở tài khoản chứng khoán thì cần thủ tục gì?
# ------------------------------------------------------------
# Reference Answer: "Theo quy định của VPS, Quý khách không được thực hiện ủy quyền cho người khác để thực hiện mở tài khoản. Việc mở tài khoản chứng khoán phải được thực hiện trực tiếp từ khách hàng có nhu cầu.Sau khi mở tài khoản chứng khoán, Quý khách có thể thực hiện ủy quyền giao dịch cho người khác nếu hồ sơ ủy quyền hợp lệ. Quý khách có thể mở tài khoản trực tuyến tại VPS qua những ứng dụng giao dịch sau:",Ứng dụng VPS SmartOne: http://bit.ly/319dmz8,,Website: https://openaccount.vps.com.vn/
# ------------------------------------------------------------
# LLM Answer: - Mở tài khoản giao dịch chứng khoán: Bạn cần chuẩn bị các giấy tờ sau:- CMND/CCCD còn hiệu lực.
# ------------------------------------------------------------
# F1 Score: 0.6812
#
# ####################################################################################################
# Question: "Tôi đã mở tài khoản trực tuyến trên ứng dụng VPS SmartOne, vậy tôi có phải gửi hồ sơ bản cứng tới VPS không?"
# ------------------------------------------------------------
# Reference Answer: "Trường hợp Quý khách thực hiện mở tài khoản chứng khoán trên ứng dụng VPS SmartOne và đã xác thực eKYC thành công, tài khoản sẽ được kích hoạt và Quý khách không cần gửi hồ sơ bản cứng tới VPS để hoàn thiện thủ tục mở tài khoản."
# ------------------------------------------------------------
# LLM Answer: - Xác nhận eKYC thành công.
# - Yêu cầu hoàn thiện thủ tục mở tài khoản.
# - Thông báo về việc mở tài khoản trực tuyến tại VPS.
# - Hỗ trợ liên lạc với các điểm giao dịch hoặc Tổng đài 1900 để được hỗ trợ thông tin.
# ------------------------------------------------------------
# F1 Score: 0.7442
#
# ####################################################################################################
# Question: Tôi là người nước ngoài và muốn mở tài khoản giao dịch chứng khoán thì cần làm những thủ tục gì?
# ------------------------------------------------------------
# Reference Answer: "Quý khách có thể đến trực tiếp Trụ sở chính/chi nhánh của VPS để thực hiện thủ tục mở tài khoản. Đối với nhà đầu tư cá nhân nước ngoài, Quý khách cần chuẩn bị các giấy tờ sau:- 03 bản sao công chứng hộ chiếu còn hiệu lực với thời hạn trong vòng 06 tháng;- Bản chụp Giấy mở tài khoản vốn đầu tư gián tiếp tại Ngân hàng;- Bản sao giấy chứng nhận đăng ký mã số giao dịch chứng khoán (trading code) hợp lệ (nếu có).Đối với nhà đầu tư Tổ chức, Quý khách vui lòng liên hệ trực tiếp tại các điểm giao dịch hoặc Tổng đài 1900 6457 để được hỗ trợ thông tin."
# ------------------------------------------------------------
# LLM Answer: - Mở tài khoản giao dịch chứng khoán
# ------------------------------------------------------------
# F1 Score: 0.6808
#
# ####################################################################################################
# Question: "Để mở tài khoản tại VPS, tôi cần có giấy tờ gì?"
# ------------------------------------------------------------
# Reference Answer: "Để thực hiện mở tài khoản chứng khoán tại VPS, Quý khách cần cung cấp một trong các loại giấy tờ sau:",Căn cước công dân còn hiệu lực.Căn cước còn hiệu lực.
# ------------------------------------------------------------
# LLM Answer: Hiện tại, để mở tài khoản giao dịch chứng khoán tại VPS, bạn cần cung cấp một trong các loại giấy tờ sau: căn cước công dân còn hiệu lực.
# ------------------------------------------------------------
# F1 Score: 0.8793
#
# ####################################################################################################

# %% [markdown]
# #### LLM test without RAG
